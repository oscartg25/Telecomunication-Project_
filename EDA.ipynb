# %%
#imprtamos las librerias que vamos a necesitar
import pandas as pd
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv("Dataset\Internet_Penetracion.csv")

# %%
df1
# Out:
#       Año  Trimestre            Provincia Accesos por cada 100 hogares
# 0    2022          3         Buenos Aires                        78,11
# 1    2022          3      Capital Federal                       122,28
# 2    2022          3            Catamarca                        65,33
# 3    2022          3                Chaco                        43,86
# 4    2022          3               Chubut                        84,38
# ..    ...        ...                  ...                          ...
# 835  2014          1           Santa Cruz                        28,94
# 836  2014          1             Santa Fe                        47,85
# 837  2014          1  Santiago Del Estero                        16,31
# 838  2014          1     Tierra Del Fuego                        63,97
# 839  2014          1              Tucumán                        33,42
#
# [840 rows x 4 columns]

# %%
# Verificar si hay valores nulos o faltantes en el dataframe
print(df1.isnull().sum())
# Out:
# Año                             0
# Trimestre                       0
# Provincia                       0
# Accesos por cada 100 hogares    0
# dtype: int64

# %%
# Obtenemos información sobre las columnas y tipos de datos
print(df1.info())

# Resumen estadístico de las variables numéricas
print(df1.describe())

# Dimensiones del dataset
print(df1.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 840 entries, 0 to 839
# Data columns (total 4 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Año                           840 non-null    int64
#  1   Trimestre                     840 non-null    int64
#  2   Provincia                     840 non-null    object
#  3   Accesos por cada 100 hogares  840 non-null    object
# dtypes: int64(2), object(2)
# memory usage: 26.4+ KB
# None
#                Año   Trimestre
# count   840.000000  840.000000
# mean   2017.885714    2.457143
# std       2.528745    1.105009
# min    2014.000000    1.000000
# 25%    2016.000000    1.000000
# 50%    2018.000000    2.000000
# 75%    2020.000000    3.000000
# max    2022.000000    4.000000
# (840, 4)

# %%
# Reemplazar las comas por puntos en la columna "Accesos por cada 100 hogares"
df1['Accesos por cada 100 hogares'] = df1['Accesos por cada 100 hogares'].str.replace(',', '.')

# %%
# Convertir los valores a tipo numérico
df1['Accesos por cada 100 hogares'] = pd.to_numeric(df1['Accesos por cada 100 hogares'])

# %%
# Filtrar los datos para el año 2022
df_2022 = df1[df1['Año'] == 2022]

# %%
# Calcular la media del acceso por cada 100 hogares por provincia en el año 2022
media_por_provincia = df_2022.groupby('Provincia')['Accesos por cada 100 hogares'].mean().round(2)

# Imprimir los resultados
print(media_por_provincia)
# Out:
# Provincia
# Buenos Aires            77.26
# Capital Federal        118.46
# Catamarca               61.98
# Chaco                   43.90
# Chubut                  85.21
# Corrientes              48.07
# Córdoba                 87.18
# Entre Ríos              63.76
# Formosa                 40.71
# Jujuy                   58.10
# La Pampa                93.74
# La Rioja                79.86
# Mendoza                 49.72
# Misiones                50.62
# Neuquén                 78.19
# Río Negro               67.62
# Salta                   57.14
# San Juan                47.94
# San Luis                81.41
# Santa Cruz              43.23
# Santa Fe                77.92
# Santiago Del Estero     47.62
# Tierra Del Fuego        99.22
# Tucumán                 59.28
# Name: Accesos por cada 100 hogares, dtype: float64

# %%
desviacion_estandar_por_provincia = df_2022.groupby('Provincia')['Accesos por cada 100 hogares'].std()
print("\nDesviación Estándar:")
print(desviacion_estandar_por_provincia)
# Out:
# Desviación Estándar:
# Provincia
# Buenos Aires           1.052917
# Capital Federal        5.790961
# Catamarca              3.578533
# Chaco                  0.140119
# Chubut                 2.533265
# Corrientes             0.376076
# Córdoba                1.300628
# Entre Ríos             0.125033
# Formosa                4.985432
# Jujuy                  0.795634
# La Pampa               2.552104
# La Rioja               0.976337
# Mendoza                1.180127
# Misiones               1.428426
# Neuquén                3.482935
# Río Negro              0.509346
# Salta                  0.895898
# San Juan               3.857594
# San Luis               0.594755
# Santa Cruz             0.100167
# Santa Fe               0.625167
# Santiago Del Estero    0.411380
# Tierra Del Fuego       0.824197
# Tucumán                1.875180
# Name: Accesos por cada 100 hogares, dtype: float64

# %%
# Filtrar los datos para el año 2022
df_2022 = df1[df1['Año'] == 2022]

# Calcular la media del acceso por cada 100 hogares por provincia en el año 2022
media_por_provincia = df_2022.groupby('Provincia')['Accesos por cada 100 hogares'].mean().round(2)

# Imprimir los resultados
print(media_por_provincia)
# Out:
# Provincia
# Buenos Aires            77.26
# Capital Federal        118.46
# Catamarca               61.98
# Chaco                   43.90
# Chubut                  85.21
# Corrientes              48.07
# Córdoba                 87.18
# Entre Ríos              63.76
# Formosa                 40.71
# Jujuy                   58.10
# La Pampa                93.74
# La Rioja                79.86
# Mendoza                 49.72
# Misiones                50.62
# Neuquén                 78.19
# Río Negro               67.62
# Salta                   57.14
# San Juan                47.94
# San Luis                81.41
# Santa Cruz              43.23
# Santa Fe                77.92
# Santiago Del Estero     47.62
# Tierra Del Fuego        99.22
# Tucumán                 59.28
# Name: Accesos por cada 100 hogares, dtype: float64

# %% [markdown]
# # Histograma historico

# %%
# Histograma de la variable 'Accesos por cada 100 hogares'
plt.hist(df1['Accesos por cada 100 hogares'], bins=10)
plt.xlabel('Accesos por cada 100 hogares')
plt.ylabel('Frecuencia')
plt.title('Distribución de la Penetración de Internet')
plt.show()

# %%
# Obtener el valor mínimo y máximo de la columna 'Accesos por cada 100 hogares'
min_penetration = df1['Accesos por cada 100 hogares'].min()
max_penetration = df1['Accesos por cada 100 hogares'].max()

# Obtener las provincias con la menor y mayor penetración relativa
province_min = df1.loc[df1['Accesos por cada 100 hogares'] == min_penetration, 'Provincia'].values[0]
province_max = df1.loc[df1['Accesos por cada 100 hogares'] == max_penetration, 'Provincia'].values[0]

# Imprimir los resultados
print("Provincia con la menor penetración de internet:", province_min)
print("Provincia con la mayor penetración de internet:", province_max)
# Out:
# Provincia con la menor penetración de internet: San Luis
# Provincia con la mayor penetración de internet: Capital Federal

# %%
df_promedio = df1.groupby('Provincia')['Accesos por cada 100 hogares'].mean()

# Crear la figura y los ejes
fig, ax = plt.subplots()

# Crear la figura y los ejes
fig, ax = plt.subplots()

# Configurar los datos para el gráfico de barras
provincias = df_promedio.index
promedios = df_promedio.values

# Crear el gráfico de barras
ax.bar(provincias, promedios)

# Configurar las etiquetas y el título del gráfico
ax.set_xlabel('Provincia')
ax.set_ylabel('Promedio por cada 100 hogares')
ax.set_title('Promedio de accesos por cada 100 hogares por provincia en 2022')

# Rotar las etiquetas del eje x para una mejor legibilidad
plt.xticks(rotation=90)

# Mostrar los valores de promedio sobre las barras
for i, v in enumerate(promedios):
    ax.text(i, v, str(round(v, 2)), ha='center', va='bottom')

# %% [markdown]
# # analisis bivariados

# %%
# Obtener los datos del DataFrame
x = df1['Accesos por cada 100 hogares']  # Datos para el eje x
y = df1['Provincia']  # Datos para el eje y

# Crear el gráfico de dispersión
plt.scatter(x, y)

# Configurar etiquetas y título
plt.xlabel('Accesos por cada 100 hogares')
plt.ylabel('Provincia')
plt.title('Gráfico de Dispersión')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# # OUTLIERS

# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.read_csv("Dataset/Internet_Penetracion.csv")

# %%
df1
# Out:
#       Año  Trimestre            Provincia Accesos por cada 100 hogares
# 0    2022          3         Buenos Aires                        78,11
# 1    2022          3      Capital Federal                       122,28
# 2    2022          3            Catamarca                        65,33
# 3    2022          3                Chaco                        43,86
# 4    2022          3               Chubut                        84,38
# ..    ...        ...                  ...                          ...
# 835  2014          1           Santa Cruz                        28,94
# 836  2014          1             Santa Fe                        47,85
# 837  2014          1  Santiago Del Estero                        16,31
# 838  2014          1     Tierra Del Fuego                        63,97
# 839  2014          1              Tucumán                        33,42
#
# [840 rows x 4 columns]

# %%
# Convertir la columna a tipo numérico y cambiar la coma por punto
df1['Accesos por cada 100 hogares'] = df1['Accesos por cada 100 hogares'].str.replace(',', '.').astype(float)

# %%
# Calcular el rango intercuartil (IQR)
Q1 = df1['Accesos por cada 100 hogares'].quantile(0.25)
Q3 = df1['Accesos por cada 100 hogares'].quantile(0.75)
IQR = Q3 - Q1

# %%
# Definir los límites para detectar outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df1[(df1['Accesos por cada 100 hogares'] < lower_bound) | (df1['Accesos por cada 100 hogares'] > upper_bound)]

# Imprimir los outliers
print(outliers)
# Out:
#       Año  Trimestre        Provincia  Accesos por cada 100 hogares
# 1    2022          3  Capital Federal                        122.28
# 25   2022          2  Capital Federal                        121.31
# 49   2022          1  Capital Federal                        111.80
# 73   2021          4  Capital Federal                        111.27
# 97   2021          3  Capital Federal                        111.27
# 121  2021          2  Capital Federal                        110.14
# 145  2021          1  Capital Federal                        108.42
# 169  2020          4  Capital Federal                        108.31
# 193  2020          3  Capital Federal                        107.68
# 289  2019          3  Capital Federal                        112.65
# 313  2019          2  Capital Federal                        110.55
# 337  2019          1  Capital Federal                        109.20
# 361  2018          4  Capital Federal                        108.27
# 385  2018          3  Capital Federal                        108.45
# 409  2018          2  Capital Federal                        106.53
# 457  2017          4  Capital Federal                        122.90
# 481  2017          3  Capital Federal                        121.86
# 505  2017          2  Capital Federal                        124.06
# 529  2017          1  Capital Federal                        108.37
# 553  2016          4  Capital Federal                        120.63
# 577  2016          3  Capital Federal                        120.77
# 601  2016          2  Capital Federal                        120.04
# 625  2016          1  Capital Federal                        115.16
# 649  2015          4  Capital Federal                        118.13
# 673  2015          3  Capital Federal                        118.29
# 697  2015          2  Capital Federal                        116.07
# 721  2015          1  Capital Federal                        114.90
# 745  2014          4  Capital Federal                        114.90
# 769  2014          3  Capital Federal                        113.80
# 793  2014          2  Capital Federal                        113.14
# 817  2014          1  Capital Federal                        112.25

# %%
import seaborn as sns

# %%
# Crear un boxplot
plt.figure(figsize=(8, 6))
sns.boxplot(data=df1, y='Accesos por cada 100 hogares')

# Agregar título y etiquetas de los ejes
plt.title('Boxplot de la Penetración de Internet')
plt.ylabel('Accesos por cada 100 hogares')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# # Internet banda ancha y banda angosta

# %%
df2 = pd.read_csv('Dataset/Internet_BAAp.csv')

# %%
df2
# Out:
#       Año  Trimestre            Provincia Banda ancha fija Dial up      Total
# 0    2022          3         Buenos Aires        4.715.469   6.199  4.721.668
# 1    2022          3      Capital Federal        1.545.534   2.145  1.547.679
# 2    2022          3            Catamarca           70.292       1     70.293
# 3    2022          3                Chaco          144.141       5    144.146
# 4    2022          3               Chubut          164.874     904    165.778
# ..    ...        ...                  ...              ...     ...        ...
# 835  2014          1           Santa Cruz           26.304     460     26.764
# 836  2014          1             Santa Fe          506.000     612    506.612
# 837  2014          1  Santiago Del Estero           37.124       9     37.133
# 838  2014          1     Tierra Del Fuego           27.272     766     28.038
# 839  2014          1              Tucumán          129.944      88    130.032
#
# [840 rows x 6 columns]

# %%
# Verificar si hay valores nulos
print(df2.isnull().sum())
# Out:
# Año                 0
# Trimestre           0
# Provincia           0
# Banda ancha fija    0
# Dial up             2
# Total               0
# dtype: int64

# %%
# Reemplazar los valores nulos en la columna "Dial up" con 0
df2['Dial up'].fillna(0, inplace=True)

# %%
# Eliminar espacios en blanco en los nombres de las columnas
df2.columns = df2.columns.str.strip()

# Eliminar caracteres no deseados
df2['Provincia'] = df2['Provincia'].str.replace('Provincia', '')

# %% [markdown]
# # Grafico de provincia vs años

# %%
# Filtrar los últimos 10 años de datos
df_last_10_years = df2[df2['Año'] >= df2['Año'].max() - 9]

# %%
# Eliminar los puntos de los valores en la columna "Banda ancha fija" y convertirlos en números enteros
df2['Banda ancha fija'] = df2['Banda ancha fija'].str.replace('.', '').astype(int)

# %%
# Filtrar los últimos 10 años de datos
df_last_10_years = df2[df2['Año'] >= df2['Año'].max() - 9]

# Calcular el promedio por provincia
df_promedio_provincia = df_last_10_years.groupby('Provincia')['Banda ancha fija'].mean()

# Mostrar el resultado
print(df_promedio_provincia)
# Out:
# Provincia
# Buenos Aires           3.514696e+06
# Capital Federal        1.396189e+06
# Catamarca              3.748020e+04
# Chaco                  1.050919e+05
# Chubut                 9.510911e+04
# Corrientes             1.021817e+05
# Córdoba                7.503283e+05
# Entre Ríos             2.071252e+05
# Formosa                3.986834e+04
# Jujuy                  6.869997e+04
# La Pampa               8.185731e+04
# La Rioja               4.297891e+04
# Mendoza                1.996097e+05
# Misiones               1.181859e+05
# Neuquén                1.177800e+05
# Río Negro              1.184898e+05
# Salta                  1.401395e+05
# San Juan               6.419317e+04
# San Luis               6.208163e+04
# Santa Cruz             3.368360e+04
# Santa Fe               6.841152e+05
# Santiago Del Estero    7.715469e+04
# Tierra Del Fuego       3.788794e+04
# Tucumán                1.794899e+05
# Name: Banda ancha fija, dtype: float64

# %%
# Filtrar los últimos 10 años de datos
df_last_10_years = df2[df2['Año'] >= df2['Año'].max() - 9]

# Calcular el promedio año tras año
df_promedio_anual = df_last_10_years.groupby('Año')['Banda ancha fija'].mean()

# Mostrar el resultado
print(df_promedio_anual)
# Out:
# Año
# 2014    269884.093750
# 2015    284766.135417
# 2016    295560.166667
# 2017    314768.958333
# 2018    342349.770833
# 2019    369694.729167
# 2020    382616.708333
# 2021    417112.239583
# 2022    453282.347222
# Name: Banda ancha fija, dtype: float64

# %%
# Crear un gráfico de línea
plt.figure(figsize=(10, 6))
plt.plot(df_promedio_anual.index, df_promedio_anual.values, marker='o')

# Agregar título y etiquetas de los ejes
plt.title('Promedio de Banda Ancha Fija Año Tras Año')
plt.xlabel('Año')
plt.ylabel('Promedio de Banda Ancha Fija')

# Rotar las etiquetas del eje x para una mejor legibilidad
plt.xticks(rotation=45)

# Mostrar el gráfico
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
# Calcular el promedio anual de Banda ancha fija por provincia
df_promedio_provincia = df2.groupby(['Provincia', 'Año'])['Banda ancha fija'].mean().reset_index()

# Mostrar el resultado
print(df_promedio_provincia)
# Out:
#         Provincia   Año  Banda ancha fija
# 0    Buenos Aires  2014      2.778219e+06
# 1    Buenos Aires  2015      2.895242e+06
# 2    Buenos Aires  2016      3.042391e+06
# 3    Buenos Aires  2017      3.115892e+06
# 4    Buenos Aires  2018      3.545308e+06
# ..            ...   ...               ...
# 211       Tucumán  2018      1.702648e+05
# 212       Tucumán  2019      1.752472e+05
# 213       Tucumán  2020      2.180250e+05
# 214       Tucumán  2021      2.339930e+05
# 215       Tucumán  2022      2.543793e+05
#
# [216 rows x 3 columns]

# %%
fig, ax = plt.subplots(figsize=(12, 6))

# Obtener las provincias únicas y los años únicos
provincias_unicas = df_promedio_provincia['Provincia'].unique()
anios_unicos = df_promedio_provincia['Año'].unique()

# Configurar los datos de los ejes x e y
x = range(len(provincias_unicas))
width = 0.15

# Crear las barras para cada año
for i, anio in enumerate(anios_unicos):
    promedios_anio = df_promedio_provincia[df_promedio_provincia['Año'] == anio]['Banda ancha fija']
    ax.bar([pos + i * width for pos in x], promedios_anio, width=width, label=str(anio))

# Configurar los ejes y etiquetas
ax.set_xlabel('Provincia')
ax.set_ylabel('Promedio de Banda Ancha Fija')
ax.set_title('Promedio de Banda Ancha Fija por Provincia y Año')
ax.set_xticks(x)
ax.set_xticklabels(provincias_unicas, rotation=45)
ax.legend()

# Mostrar el gráfico
plt.show()

# %% [markdown]
# # Grafico provincia vs dial up

# %%
import matplotlib.pyplot as plt
import re

# %%
# Limpiar los datos en la columna "Dial up"
df2['Dial up'] = df2['Dial up'].apply(lambda x: re.sub(r'[^0-9.]', '', str(x))).replace('', '0').astype(float)

# %%
df2['Dial up']
# Out:
# 0        6.199
# 1        2.145
# 2        1.000
# 3        5.000
# 4      904.000
#         ...
# 835    460.000
# 836    612.000
# 837      9.000
# 838    766.000
# 839     88.000
# Name: Dial up, Length: 840, dtype: float64

# %%
df2['Dial up'] = df2['Dial up'].astype(str).str.replace('.', '').astype(int)

# %%
# Calcular el promedio anual de Dial up por provincia
df_promedio_provincia = df2.groupby(['Provincia', 'Año'])['Dial up'].mean().reset_index()

# Configurar el gráfico
fig, ax = plt.subplots(figsize=(12, 6))

# Obtener las provincias únicas y los años únicos
provincias_unicas = df_promedio_provincia['Provincia'].unique()
anios_unicos = df_promedio_provincia['Año'].unique()

# Configurar los datos de los ejes x e y
x = range(len(provincias_unicas))
width = 0.15

# Crear las barras para cada año
for i, anio in enumerate(anios_unicos):
    promedios_anio = df_promedio_provincia[df_promedio_provincia['Año'] == anio]['Dial up']
    ax.bar([pos + i * width for pos in x], promedios_anio, width=width, label=str(anio))

# Configurar los ejes y etiquetas
ax.set_xlabel('Provincia')
ax.set_ylabel('Promedio de Dial up')
ax.set_title('Promedio de Dial up por Provincia y Año')
ax.set_xticks(x)
ax.set_xticklabels(provincias_unicas, rotation=45)
ax.legend()

# Mostrar el gráfico
plt.show()

# %% [markdown]
# # Ingresos internet

# %%
# Leer el archivo CSV
df_ingresos = pd.read_csv('Dataset/Internet_Ingresos.csv', encoding='utf-8')

# %%
# Eliminar decimales y convertir los valores a enteros
df_ingresos['Ingresos (miles de pesos)'] = df_ingresos['Ingresos (miles de pesos)'].astype(str)
df_ingresos['Ingresos (miles de pesos)'] = df_ingresos['Ingresos (miles de pesos)'].str.replace('.', '').astype(int)

# Mostrar las primeras filas del DataFrame actualizado
print(df_ingresos.head())
# Out:
#     Año  Trimestre  Ingresos (miles de pesos)        Periodo
# 0  2022          3                   67055930  Jul-Sept 2022
# 1  2022          2                   60335724   Abr-Jun 2022
# 2  2022          1                   55589997   Ene-Mar 2022
# 3  2021          4                   45467887   Oct-Dic 2021
# 4  2021          3                   42999944  Jul-Sept 2021

# %%
df_ingresos['Trimestre']
# Out:
# 0     3
# 1     2
# 2     1
# 3     4
# 4     3
# 5     2
# 6     1
# 7     4
# 8     3
# 9     2
# 10    1
# 11    4
# 12    3
# 13    2
# 14    1
# 15    4
# 16    3
# 17    2
# 18    1
# 19    4
# 20    3
# 21    2
# 22    1
# 23    4
# 24    3
# 25    2
# 26    1
# 27    4
# 28    3
# 29    2
# 30    1
# 31    4
# 32    3
# 33    2
# 34    1
# Name: Trimestre, dtype: int64

# %%
# Mapeo de trimestres a números
# trimestres = {'Ene': 1, 'Feb': 2, 'Mar': 3, 'Abr': 4, 'May': 5, 'Jun': 6, 'Jul': 7, 'Ago': 8, 'Sep': 9, 'Oct': 10, 'Nov': 11, 'Dic': 12}

# %%
# Convertir trimestres a números
# df_ingresos['Trimestre'] = df_ingresos['Periodo'].str.split('-').str[0].map(Trimestres)

# Convertir año a entero
df_ingresos['Año'] = df_ingresos['Año'].astype(int)

# %%
df_ingresos['Trimestre']
# Out:
# 0     3
# 1     2
# 2     1
# 3     4
# 4     3
# 5     2
# 6     1
# 7     4
# 8     3
# 9     2
# 10    1
# 11    4
# 12    3
# 13    2
# 14    1
# 15    4
# 16    3
# 17    2
# 18    1
# 19    4
# 20    3
# 21    2
# 22    1
# 23    4
# 24    3
# 25    2
# 26    1
# 27    4
# 28    3
# 29    2
# 30    1
# 31    4
# 32    3
# 33    2
# 34    1
# Name: Trimestre, dtype: int64

# %%
import re

# %%
# Filtrar los datos solo para los años requeridos
años = [2018, 2019, 2020, 2022]
df_años = df_ingresos[df_ingresos['Año'].isin(años)]

# Calcular el promedio de ingresos por trimestre y año
df_promedio_trimestre = df_años.groupby(['Año', 'Trimestre'])['Ingresos (miles de pesos)'].mean()

# Mostrar el promedio de ingresos por trimestre y año
for año in años:
    promedios_año = df_promedio_trimestre.loc[año]
    print(f"Promedio de ingresos por trimestre en el año {año}:")
    print(promedios_año)
    print()
# Out:
# Promedio de ingresos por trimestre en el año 2018:
# Trimestre
# 1    13171459.0
# 2    14319467.0
# 3    15410981.0
# 4    16637687.0
# Name: Ingresos (miles de pesos), dtype: float64
#
# Promedio de ingresos por trimestre en el año 2019:
# Trimestre
# 1    20207414.0
# 2    20743118.0
# 3    21652748.0
# 4    24169251.0
# Name: Ingresos (miles de pesos), dtype: float64
#
# Promedio de ingresos por trimestre en el año 2020:
# Trimestre
# 1    29946216.0
# 2    32102476.0
# 3    31997445.0
# 4    33539703.0
# Name: Ingresos (miles de pesos), dtype: float64
#
# Promedio de ingresos por trimestre en el año 2022:
# Trimestre
# 1    55589997.0
# 2    60335724.0
# 3    67055930.0
# Name: Ingresos (miles de pesos), dtype: float64

# %% [markdown]
# #graficamos

# %%
# Graficar el promedio de ingresos por trimestre en cada año
fig, ax = plt.subplots()

for año in años:
    promedios_año = df_promedio_trimestre.loc[año]
    ax.plot(promedios_año.index, promedios_año.values, marker='o', label=str(año))

# Configurar los ejes y etiquetas
ax.set_xlabel('Trimestre')
ax.set_ylabel('Promedio de Ingresos (miles de pesos)')
ax.set_title('Promedio de Ingresos por Trimestre y Año')
ax.legend(title='Año')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# # Distintas tecnologias del internet

# %%
# Leer el archivo CSV
df_tecnologia = pd.read_csv('Dataset/Internet_Accesos-por-tecnologia.csv')

# %%
columnas = ['ADSL', 'Cablemodem', 'Fibra óptica', 'Wireless', 'Otros', 'Total']

for columna in columnas:
    df_tecnologia[columna] = df_tecnologia[columna].apply(lambda x: "{:.3f}".format(x).replace('.', '') if isinstance(x, float) else x)

# %%
df_tecnologia
# Out:
#      Año  Trimestre       ADSL Cablemodem Fibra óptica Wireless   Otros
# 0   2022          3  1.395.277  6.031.970    2.871.541   557110  235230  \
# 1   2022          2  1.468.333  5.979.214    2.723.285   556243  231609
# 2   2022          1  1.533.240  6.073.426    2.219.533   545814  251996
# 3   2021          4  1.657.615  5.984.240    2.072.236   523107  252596
# 4   2021          3  1.950.631  5.826.257    1.566.048   492415  250190
# 5   2021          2  2.018.587  5.641.731    1.472.246   476968  253552
# 6   2021          1  2.175.211  5.424.782    1.362.976   434548  250455
# 7   2020          4  2.213.949  5.371.824    1.311.199   421554  253036
# 8   2020          3  2.263.889  5.259.351    1.170.879   413259  248821
# 9   2020          2  2.295.533  5.005.115    1.106.725   376667  247016
# 10  2020          1  2.299.457  4.903.674    1.047.817   352333  209145
# 11  2019          4  2.414.575  4.883.869      941.295   340144  213298
# 12  2019          3  2.909.805  4.800.091      852.221   338241  264326
# 13  2019          2  2.990.457  4.635.575      760.794   308027  265328
# 14  2019          1  3.132.789  4.435.439      637.099   276419  166389
# 15  2018          4  3.329.027  4.313.831      388.013   264299  178485
# 16  2018          3  3.521.447  4.238.171      247.366   246181   93870
# 17  2018          2  3.557.216  4.038.141      226.285   194267   94535
# 18  2018          1  3.574.294  3.981.129      217.460   165300   98870
# 19  2017          4  3.584.311  3.818.157      211.425   155775  100554
# 20  2017          3  3.622.575  3.670.221      193.964   106443  131740
# 21  2017          2  3.723.518  3.383.434      180.777    85813   56122
# 22  2017          1  3.708.898  3.276.251      180.146    84813   55746
# 23  2016          4  3.722.794  3.210.602      178.070    85119   55088
# 24  2016          3  3.776.442  3.124.855      169.898    81455   54300
# 25  2016          2  3.782.085  3.035.272      167.788    85452   59482
# 26  2016          1  3.792.493  2.806.359      164.371    85370   58763
# 27  2015          4  3.803.024  2.898.226      139.187    85726   58668
# 28  2015          3  3.788.696  2.840.203      162.663    84530   58976
# 29  2015          2  3.767.821  2.756.294      150.839    82077   59157
# 30  2015          1  3.756.153  2.668.248      168.188    79098   66045
# 31  2014          4  3.764.038  2.536.219      149.682    76984   71573
# 32  2014          3  3.714.764  2.569.868      155.494    85096   70049
# 33  2014          2  3.708.882  2.461.670      149.363    72405   72148
# 34  2014          1  3.697.066  2.407.330      150.323    70749   72930
#
#          Total        Periodo
# 0   11.091.128  Jul-Sept 2022
# 1   10.958.684   Abr-Jun 2022
# 2   10.624.009   Ene-Mar 2022
# 3   10.489.794   Oct-Dic 2021
# 4   10.085.541  Jul-Sept 2021
# 5    9.863.084   Abr-Jun 2021
# 6    9.647.972   Ene-Mar 2021
# 7    9.571.562   Oct-Dic 2020
# 8    9.356.199  Jul-Sept 2020
# 9    9.031.056   Abr-Jun 2020
# 10   8.812.426   Ene-Mar 2020
# 11   8.793.181   Oct-Dic 2019
# 12   9.164.684  Jul-Sept 2019
# 13   8.960.181   Abr-Jun 2019
# 14   8.648.135   Ene-Mar 2019
# 15   8.473.655   Oct-Dic 2018
# 16   8.347.035  Jul-Sept 2018
# 17   8.110.444   Abr-Jun 2018
# 18   8.037.053   Ene-Mar 2018
# 19   7.870.222   Oct-Dic 2017
# 20   7.724.943  Jul-Sept 2017
# 21   7.429.664   Abr-Jun 2017
# 22   7.305.854   Ene-Mar 2017
# 23   7.251.673   Oct-Dic 2016
# 24   7.206.950  Jul-Sept 2016
# 25   7.130.079   Abr-Jun 2016
# 26   6.907.356   Ene-Mar 2016
# 27   6.984.831   Oct-Dic 2015
# 28   6.935.068  Jul-Sept 2015
# 29   6.816.188   Abr-Jun 2015
# 30   6.737.732   Ene-Mar 2015
# 31   6.598.496   Oct-Dic 2014
# 32   6.595.271  Jul-Sept 2014
# 33   6.464.468   Abr-Jun 2014
# 34   6.398.398   Ene-Mar 2014

# %%
columnas = ['ADSL', 'Cablemodem', 'Fibra óptica', 'Wireless', 'Otros', 'Total']

formatos = df_tecnologia[columnas].dtypes
print(formatos)
# Out:
# ADSL            object
# Cablemodem      object
# Fibra óptica    object
# Wireless        object
# Otros           object
# Total           object
# dtype: object

# %%
#convertimos los datos a enteros en las respectivas columnas
columnas = ['ADSL', 'Cablemodem', 'Fibra óptica', 'Wireless', 'Otros', 'Total']

df_tecnologia[columnas] = df_tecnologia[columnas].replace('\.', '', regex=True).astype(int)

# %%
df_tecnologia
# Out:
#      Año  Trimestre     ADSL  Cablemodem  Fibra óptica  Wireless   Otros
# 0   2022          3  1395277     6031970       2871541    557110  235230  \
# 1   2022          2  1468333     5979214       2723285    556243  231609
# 2   2022          1  1533240     6073426       2219533    545814  251996
# 3   2021          4  1657615     5984240       2072236    523107  252596
# 4   2021          3  1950631     5826257       1566048    492415  250190
# 5   2021          2  2018587     5641731       1472246    476968  253552
# 6   2021          1  2175211     5424782       1362976    434548  250455
# 7   2020          4  2213949     5371824       1311199    421554  253036
# 8   2020          3  2263889     5259351       1170879    413259  248821
# 9   2020          2  2295533     5005115       1106725    376667  247016
# 10  2020          1  2299457     4903674       1047817    352333  209145
# 11  2019          4  2414575     4883869        941295    340144  213298
# 12  2019          3  2909805     4800091        852221    338241  264326
# 13  2019          2  2990457     4635575        760794    308027  265328
# 14  2019          1  3132789     4435439        637099    276419  166389
# 15  2018          4  3329027     4313831        388013    264299  178485
# 16  2018          3  3521447     4238171        247366    246181   93870
# 17  2018          2  3557216     4038141        226285    194267   94535
# 18  2018          1  3574294     3981129        217460    165300   98870
# 19  2017          4  3584311     3818157        211425    155775  100554
# 20  2017          3  3622575     3670221        193964    106443  131740
# 21  2017          2  3723518     3383434        180777     85813   56122
# 22  2017          1  3708898     3276251        180146     84813   55746
# 23  2016          4  3722794     3210602        178070     85119   55088
# 24  2016          3  3776442     3124855        169898     81455   54300
# 25  2016          2  3782085     3035272        167788     85452   59482
# 26  2016          1  3792493     2806359        164371     85370   58763
# 27  2015          4  3803024     2898226        139187     85726   58668
# 28  2015          3  3788696     2840203        162663     84530   58976
# 29  2015          2  3767821     2756294        150839     82077   59157
# 30  2015          1  3756153     2668248        168188     79098   66045
# 31  2014          4  3764038     2536219        149682     76984   71573
# 32  2014          3  3714764     2569868        155494     85096   70049
# 33  2014          2  3708882     2461670        149363     72405   72148
# 34  2014          1  3697066     2407330        150323     70749   72930
#
#        Total        Periodo
# 0   11091128  Jul-Sept 2022
# 1   10958684   Abr-Jun 2022
# 2   10624009   Ene-Mar 2022
# 3   10489794   Oct-Dic 2021
# 4   10085541  Jul-Sept 2021
# 5    9863084   Abr-Jun 2021
# 6    9647972   Ene-Mar 2021
# 7    9571562   Oct-Dic 2020
# 8    9356199  Jul-Sept 2020
# 9    9031056   Abr-Jun 2020
# 10   8812426   Ene-Mar 2020
# 11   8793181   Oct-Dic 2019
# 12   9164684  Jul-Sept 2019
# 13   8960181   Abr-Jun 2019
# 14   8648135   Ene-Mar 2019
# 15   8473655   Oct-Dic 2018
# 16   8347035  Jul-Sept 2018
# 17   8110444   Abr-Jun 2018
# 18   8037053   Ene-Mar 2018
# 19   7870222   Oct-Dic 2017
# 20   7724943  Jul-Sept 2017
# 21   7429664   Abr-Jun 2017
# 22   7305854   Ene-Mar 2017
# 23   7251673   Oct-Dic 2016
# 24   7206950  Jul-Sept 2016
# 25   7130079   Abr-Jun 2016
# 26   6907356   Ene-Mar 2016
# 27   6984831   Oct-Dic 2015
# 28   6935068  Jul-Sept 2015
# 29   6816188   Abr-Jun 2015
# 30   6737732   Ene-Mar 2015
# 31   6598496   Oct-Dic 2014
# 32   6595271  Jul-Sept 2014
# 33   6464468   Abr-Jun 2014
# 34   6398398   Ene-Mar 2014

# %%
df_tecnologia[columnas].dtypes
# Out:
# ADSL            int32
# Cablemodem      int32
# Fibra óptica    int32
# Wireless        int32
# Otros           int32
# Total           int32
# dtype: object

# %%
# Obtener los datos de las tecnologías
tecnologias = ['ADSL', 'Cablemodem', 'Fibra óptica', 'Wireless', 'Otros']
valores = [
    df_tecnologia['ADSL'].sum(),
    df_tecnologia['Cablemodem'].sum(),
    df_tecnologia['Fibra óptica'].sum(),
    df_tecnologia['Wireless'].sum(),
    df_tecnologia['Otros'].sum()
]

# %%
# Crear el gráfico de barras
plt.figure(figsize=(10, 6))
plt.bar(tecnologias, valores)

# Configurar los ejes y etiquetas
plt.xlabel('Tecnología de Acceso')
plt.ylabel('Cantidad')
plt.title('Comparación de Tecnologías de Acceso a Internet')

# Mostrar el gráfico
plt.show()
